# %%
import random

mylist = []

for i in range(0,1000):
    x = random.randint(0,100)
    mylist.append(x)

print(mylist)
# Out:
# [95, 86, 33, 61, 19, 48, 53, 36, 81, 59, 32, 97, 83, 6, 85, 97, 6, 70, 75, 8, 70, 52, 58, 14, 70, 82, 11, 11, 66, 77, 88, 69, 38, 69, 74, 54, 28, 3, 80, 34, 93, 37, 16, 25, 56, 11, 64, 100, 26, 41, 56, 81, 64, 53, 1, 81, 55, 95, 5, 41, 80, 24, 69, 60, 64, 16, 71, 12, 80, 68, 7, 44, 80, 8, 61, 97, 10, 85, 10, 23, 41, 100, 29, 2, 25, 45, 30, 48, 35, 72, 41, 44, 75, 45, 17, 51, 59, 6, 73, 8, 15, 13, 31, 2, 1, 51, 20, 2, 98, 74, 62, 54, 18, 58, 71, 27, 21, 82, 12, 100, 60, 41, 80, 35, 4, 25, 2, 0, 56, 43, 90, 2, 43, 72, 100, 52, 48, 38, 78, 46, 66, 22, 12, 14, 31, 70, 67, 94, 67, 48, 27, 87, 39, 18, 7, 92, 31, 69, 40, 75, 99, 74, 20, 93, 92, 71, 3, 4, 83, 17, 10, 90, 77, 60, 53, 76, 58, 13, 75, 86, 44, 9, 32, 24, 1, 100, 99, 28, 86, 47, 38, 39, 90, 1, 30, 75, 56, 78, 8, 20, 81, 11, 35, 65, 53, 36, 11, 15, 71, 83, 91, 73, 56, 96, 39, 21, 37, 18, 78, 71, 41, 37, 4, 94, 30, 21, 10, 91, 56, 25, 14, 41, 64, 89, 57, 6, 85, 22, 72, 90, 57, 10, 98, 83, 93, 24, 51, 28, 97, 8, 7, 15, 88, 72, 2, 44
# ...

# %%
import numpy as np
np.savetxt("step1.csv", mylist, delimiter=",", fmt='%s')
